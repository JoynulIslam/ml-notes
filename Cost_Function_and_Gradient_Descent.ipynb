# %% [markdown]
# <a href="https://colab.research.google.com/github/JoynulIslam/ml-notes/blob/main/Cost_Function_and_Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression , SGDRegressor
from sklearn.metrics import mean_squared_error

# %%
#Creatre Example DataSet
hours = np.array([2,4,6,8,10]).reshape(-1,1)
marks = np.array([55,60,70,80,88])
hours, marks
# Out:
# (array([[ 2],
#         [ 4],
#         [ 6],
#         [ 8],
#         [10]]),
#  array([55, 60, 70, 80, 88]))

# %%
# Fit a Linear regreesion Model (Closed-from-solver)
lin_red = LinearRegression()
lin_red.fit(hours,marks)

print("m: ",lin_red.coef_[0])
print("c: ",lin_red.intercept_)
# Out:
# m:  4.3
# c:  44.8

# %%
#Compute the Cost (MSE) Using the library
pred_marks = lin_red.predict(hours)
mse_lin = mean_squared_error(marks , pred_marks)
print("MSE for LinearRegression: ",mse_lin)
# Out:
# MSE for LinearRegression:  1.5200000000000033

# %%
# Visualize the Data and Best Fit Line
plt.scatter(hours,marks,label="Actual Data")
plt.plot(hours,pred_marks,label="Best Fit Line (LinearRegression)")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Study Hours VS Marks for LR")
plt.legend()
plt.grid()
plt.show()

# %%
#Use a Gradient-Descent_Model - SGDRegressor
sgd_reg = SGDRegressor(
    max_iter=1000,
    learning_rate="invscaling",
    eta0=0.01,
    random_state=42
)
sgd_reg.fit(hours,marks)
print("m: ",sgd_reg.coef_[0])
print("c: ",sgd_reg.intercept_)

pred_sgd = sgd_reg.predict(hours)
mse_sgd = mean_squared_error(marks , pred_sgd)
print("MSE of SGDRegressor: ",mse_sgd)
# Out:
# m:  5.698065492806587
# c:  [34.47526543]
# MSE of SGDRegressor:  20.906115830567398
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(

# %%
#Compare Both Lines Visually

# %%
# Visualize the Data and Best Fit Line
plt.scatter(hours,marks,label="Actual Data")
plt.plot(hours,pred_marks,label="LinearRegression", linestyle="--")
plt.plot(hours,pred_sgd,label="SGDRegressor", linestyle="-.")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("LinearRegression VS SGDRegressor")
plt.legend()
plt.grid()
plt.show()
